# %%
import pylast
import random

# %%
# --- CONFIGURATION ---
API_KEY = "47b5c5c8f34a00a3c4dbef927f9cd2db"
USER_AGENT = "DisCloverySong/1.0"

# Connect to Last.fm (Public access only)
network = pylast.LastFMNetwork(api_key=API_KEY)

# %%
def search_by_vibe(vibe_text):
    """Searches for tracks matching a specific tag/vibe."""
    # Last.fm works best with single tags (e.g., 'dreamy', 'rock')
    tag = network.get_tag(vibe_text)
    tracks = tag.get_top_tracks(limit=10)
    if tracks:
        return random.choice(tracks).item
    return None

# %%
search_by_vibe("disco everday")
# Out:
# None

# %%
tag = network.get_tag("disco")
print(type(tag))
print(tag)
# Out:
# <class 'pylast.Tag'>
# disco

# %%
tracks = tag.get_top_tracks()
print(tracks)
# Out:
# []

# %%
print(dir(tag))
print([item for item in dir(tag) if not item.startswith('__') and not item.startswith('_')])
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_extract_cdata_from_request', '_get_params', '_get_things', '_request', 'get_name', 'get_top_albums', 'get_top_artists', 'get_top_tracks', 'get_url', 'get_weekly_album_charts', 'get_weekly_artist_charts', 'get_weekly_chart_dates', 'get_weekly_charts', 'get_weekly_track_charts', 'get_wiki', 'get_wiki_content', 'get_wiki_published_date', 'get_wiki_summary', 'name', 'network', 'ws_prefix']
# ['_extract_cdata_from_request', '_get_params', '_get_things', '_request', 'get_name', 'get_top_albums', 'get_top_artists', 'get_top_tracks', 'get_url', 'get_weekly_album_charts', 'get_weekly_artist_charts', 'get_weekly_chart_dates', 'get_weekly_charts', 'get_weekly_track_charts', 'get_wiki', 'get_wiki_content', 'get_wiki_published_date', 'get_wiki_summary', 'name', 'network', 'ws_prefix']

# %%
API_KEY = "47b5c5c8f34a00a3c4dbef927f9cd2db"
()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 API_KEY = "47b5c5c8f34a00a3c4dbef927f9cd2db"
# ----> 2 tag.getTopTags()
#
# AttributeError: 'Tag' object has no attribute 'getTopTags'
